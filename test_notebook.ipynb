# %% [markdown]
# # QuantConnect Research 笔记本
#
# **创建时间**: 2025-08-17 17:50:41
# **作者**:
# **描述**:

# %%
# 标准配置 - 每个笔记本首格必备
from QuantConnect.Configuration import Config
Config.Set("data-folder", "/Lean/Data")   # 指向容器挂载点
Config.Set("log-level", "ERROR")          # 可选：安静日志

print("配置完成")
# Out:
# 配置完成

# %%
# 导入必要的库
from QuantConnect.Research import QuantBook
from QuantConnect import Resolution
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 设置图表样式
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("库导入完成")
# Out:
# 库导入完成

# %%
# 初始化 QuantBook
qb = QuantBook()
print("QuantBook 初始化完成")
# Out:
# 20250817 21:53:22.052 TRACE:: QuantBook started; Is Python: True
# 20250817 21:53:22.090 TRACE:: Config.GetValue(): downloader-data-update-period - Using default value: 7
# 20250817 21:53:22.093 TRACE:: Config.Get(): Configuration key not found. Key: databases-refresh-period - Using default value: 1.00:00:00
# 20250817 21:53:22.487 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20250817 21:53:22.490 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20250817 21:53:22.490 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20250817 21:53:22.490 TRACE:: Config.Get(): Configuration key not found. Key: data-monitor - Using default value: QuantConnect.Data.DataMonitor
# 20250817 21:53:22.495 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250817 21:53:22.495 TRACE:: Config.Get(): Configuration key not found. Key: fundamental-data-provider - Using default value: CoarseFundamentalDataProvider
# 20250817 21:53:22.496 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-capacity - Using default value: 120
# 20250817 21:53:22.496 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-time-interval-minutes - Using default value: 1440
# 20250817 21:53:22.496 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-refill-amount - Using default value: 18
# 20250817 21:53:22.496 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20250817 21:53:22.497 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20250817 21:53:22.497 TRACE:: Config.GetValue(): storage-permissions - Using default value: Read=True Write=True Delete=True
# 20250817 21:53:22.498 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB. StoragePermissions Read=True Write=True Delete=True
# 20250817 21:53:22.499 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250817 21:53:22.504 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# 20250817 21:53:22.505 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform
# 20250817 21:53:22.506 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20250817 21:53:22.507 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20250817 21:53:22.508 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20250817 21:53:22.508 TRACE:: Config.Get(): Configuration key not found. Key: data-monitor - Using default value: QuantConnect.Data.DataMonitor
# 20250817 21:53:22.509 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250817 21:53:22.509 TRACE:: Config.Get(): Configuration key not found. Key: fundamental-data-provider - Using default value: CoarseFundamentalDataProvider
# 20250817 21:53:22.509 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20250817 21:53:22.509 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20250817 21:53:22.509 TRACE:: Config.GetValue(): storage-permissions - Using default value: Read=True Write=True Delete=True
# 20250817 21:53:22.509 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB. StoragePermissions Read=True Write=True Delete=True
# 20250817 21:53:22.509 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250817 21:53:22.509 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# QuantBook 初始化完成
# 20250817 21:53:22.510 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform

# %% [markdown]
# ## 数据获取
#
# 在这里添加数据获取代码

# %%
# 示例：获取 SPY 数据
symbol = qb.AddEquity("SPY").Symbol
history = qb.History([symbol], 30, Resolution.Daily)
print(f"获取到 {len(history)} 条数据")
history.head()
# Out:
# 20250817 21:53:44.888 TRACE:: Config.GetValue(): data-feed-workers-count - Using default value: 32
# 20250817 21:53:44.889 TRACE:: Config.GetValue(): data-feed-max-work-weight - Using default value: 400
# 20250817 21:53:44.889 TRACE:: WeightedWorkScheduler(): will use 32 workers and MaxWorkWeight is 400
# 获取到 0 条数据
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 分析代码
#
# 在这里添加您的分析代码

# %%
# 在这里添加您的分析代码
pass
