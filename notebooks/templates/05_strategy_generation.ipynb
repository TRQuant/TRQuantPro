# %% [markdown]
# # 05. 策略生成
# **目标**: 基于有效因子组合生成交易策略
# **方法**: 因子加权、风险模型

# %%
import sys
sys.path.insert(0, '/home/taotao/dev/QuantTest/TRQuant')
from notebooks.lib import get_jqdata_client, load_research_conclusions, optimize_portfolio, save_research_conclusion
jq = get_jqdata_client()

# %%
# 加载有效因子
factor_results = load_research_conclusions(module='factor_research', limit=1)
# effective_factors = factor_results['effective_factors']

# %%
# 生成综合因子评分
# combined_score = weighted_factor_combination(factors, weights)

# %%
# 组合优化
# weights = optimize_portfolio(expected_returns, cov_matrix, method='max_sharpe')
# save_research_conclusion(...)
