# %% [markdown]
# # 04. 因子研究
# **目标**: 研究和评估选股因子有效性
# **工具**: Alphalens

# %%
import sys
sys.path.insert(0, '/home/taotao/dev/QuantTest/TRQuant')
from notebooks.lib import get_jqdata_client, analyze_factor, calculate_ic_ir, save_research_conclusion, VIZ_AVAILABLE
if VIZ_AVAILABLE: from notebooks.lib import plot_factor_analysis
jq = get_jqdata_client()

# %%
# 准备因子数据
# factor_data = calculate_momentum(prices, 20)
# ic_results = calculate_ic_ir(factor_data, forward_returns)

# %%
# 因子评估与可视化
# if VIZ_AVAILABLE: plot_factor_analysis(ic_series, 'momentum_20d')
# save_research_conclusion(...)
