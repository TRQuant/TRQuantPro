# %% [markdown]
# # 02. 市场主线识别
# **目标**: 识别市场主要投资主线和热门板块
# **方法**: 板块动量分析

# %%
import sys
sys.path.insert(0, '/home/taotao/dev/QuantTest/TRQuant')
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from notebooks.lib import get_jqdata_client, save_research_conclusion
jq = get_jqdata_client()
print('✅ 环境加载完成')

# %%
# 获取行业板块动量
END_DATE = datetime.now().strftime('%Y-%m-%d')
industries = jq.get_industries(name='sw_l1')
# 计算各行业20日、60日动量并排名...

# %%
# 识别主线行业
# mainlines = 综合动量TOP行业
# save_research_conclusion(...)
