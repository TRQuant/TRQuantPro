# %% [markdown]
# # 03. 候选池构建
# **目标**: 基于主线行业构建股票候选池
# **筛选**: 市值、基本面、技术面

# %%
import sys
sys.path.insert(0, '/home/taotao/dev/QuantTest/TRQuant')
import pandas as pd
from notebooks.lib import get_jqdata_client, load_research_conclusions, save_research_conclusion
jq = get_jqdata_client()

# %%
# 加载主线识别结果
mainline_results = load_research_conclusions(module='mainline_identification', limit=1)
# 获取主线行业股票、应用筛选条件...

# %%
# 输出候选池
# save_research_conclusion(...)
