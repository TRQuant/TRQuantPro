# %% [markdown]
# # 市场趋势判断方法验证
#
# > **模块定位**: 建立和验证市场环境判断方法，为01_market_trend_comprehensive提供方法论支撑
# >
# > **目标**: 通过10年历史数据回测，验证各种市场判断指标的有效性，优化参数阈值
#
# ---
#
# ## 📋 目录
#
# 1. [方法论框架](#1-方法论框架)
# 2. [数据源与可用性](#2-数据源与可用性)
# 3. [市场状态量化定义](#3-市场状态量化定义)
# 4. [Phase 1: 快速验证回测](#4-phase-1-快速验证回测)
# 5. [Phase 2: 完整10年回测](#5-phase-2-完整10年回测)
# 6. [结果分析与可视化](#6-结果分析与可视化)
# 7. [参数优化建议](#7-参数优化建议)
# 8. [结论与后续改进](#8-结论与后续改进)

# %%
# 环境初始化
import sys
from pathlib import Path

# 添加项目根目录到 Python 路径
project_root = Path.cwd()
while project_root.name != 'TRQuant' and project_root.parent != project_root:
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"项目根目录: {project_root}")

# 基础库
import logging
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from IPython.display import display, Markdown, HTML

# 配置日志
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# 可视化
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

print("✅ 环境初始化完成")
# Out:
# 项目根目录: /home/taotao/dev/QuantTest/TRQuant
# ✅ 环境初始化完成

# %% [markdown]
# ---
#
# ## 1. 方法论框架
#
# ### 1.1 核心理念
#
# 市场趋势判断基于**多周期共振**原理：
#
# ```
# 长期趋势 (权重50%) + 中期趋势 (权重30%) + 短期趋势 (权重20%) = 综合判断
# ```
#
# ### 1.2 三周期定义
#
# | 周期 | 时间窗口 | 分析天数 | 权重 | 核心指标 | 验证期 |
# |------|----------|----------|------|----------|--------|
# | 短期 | 1-8周 | 5-40日 | 20% | MA5/MA10/RSI14/KDJ | 5日 |
# | 中期 | 9-24周 | 45-120日 | 30% | MA20/MA60/MACD/布林带 | 20日 |
# | 长期 | 25-48周 | 125-240日 | 50% | MA120/MA250/ADX/月线趋势 | 60日 |
#
# ### 1.3 A股特色指标
#
# | 指标 | 数据源 | 权重 | 说明 |
# |------|--------|------|------|
# | 北向资金 | JQData | 35% | 外资态度，2014.11-2024.08有完整买卖数据 |
# | 融资融券 | JQData | 25% | 市场杠杆水平 |
# | 市场宽度 | JQData | 40% | 涨跌停比、涨跌家数比 |

# %% [markdown]
# ### 1.4 量化计算公式详解
#
# #### 1.4.1 8维技术指标得分计算
#
# 每个指标得分范围 **-100 ~ +100**，综合后加权平均：
#
# **1. 均线系统得分 (MA_score, 权重20%)**:
#
# ```
# MA排列得分 = {
#     MA5 > MA10 > MA20 > MA60: +40 (多头排列)
#     MA5 > MA10 > MA20:        +20
#     MA60 < 价格 < MA5:        +10
#     MA60 > MA20 > MA10 > MA5: -40 (空头排列)
#     其他:                      0
# }
#
# 价格位置得分 = {
#     价格 > MA5 * 1.05: +30 (强势)
#     价格 > MA20:       +10
#     价格 < MA60:       -20
#     价格 < MA120:      -30
# }
#
# MA_score = MA排列得分 + 价格位置得分
# ```
#
# **📝 数值示例**:
# ```
# 假设当前: 收盘价=3200, MA5=3180, MA10=3150, MA20=3100, MA60=3050, MA120=3000
# → MA5 > MA10 > MA20 > MA60 → 多头排列 +40分
# → 价格3200 > MA5*1.05=3339? 否; 价格 > MA20=3100? 是 → +10分
# → MA_score = 40 + 10 = +50
# ```
#
# **2. MACD得分 (MACD_score, 权重18%)**:
#
# ```
# MACD_score = DIF位置得分 + 柱状图得分 + 金叉死叉得分
#
# DIF位置 = {
#     DIF > 0 且 DIF > DEA: +30
#     DIF > 0 且 DIF < DEA: +10
#     DIF < 0 且 DIF > DEA: -10
#     DIF < 0 且 DIF < DEA: -30
# }
#
# 柱状图 = {
#     MACD柱 > 0 且 连续3日放大: +20
#     MACD柱 > 0:               +10
#     MACD柱 < 0 且 连续3日放大: -20
#     MACD柱 < 0:               -10
# }
#
# 金叉死叉 = {
#     5日内DIF上穿DEA: +20
#     5日内DIF下穿DEA: -20
# }
# ```
#
# **📝 数值示例**:
# ```
# 假设: DIF=15, DEA=12, MACD柱=3(红柱放大第2天)
# → DIF > 0 且 DIF > DEA → +30分
# → MACD柱 > 0 → +10分
# → 无金叉死叉 → 0分
# → MACD_score = 30 + 10 + 0 = +40
# ```
#
# **3. RSI得分 (RSI_score, 权重12%)**:
#
# ```
# RSI_score = {
#     RSI14 > 80:           -40 (极度超买)
#     RSI14 > 70:           -20 (超买)
#     RSI14 > 50:           +20 (偏强)
#     RSI14 > 30:           -10 (偏弱)
#     RSI14 > 20:           +10 (超卖反弹机会)
#     RSI14 < 20:           +30 (极度超卖)
# } + RSI背离调整
#
# RSI背离 = {
#     价格新高但RSI未新高: -30 (顶背离)
#     价格新低但RSI未新低: +30 (底背离)
# }
# ```
#
# **4. 布林带得分 (BB_score, 权重12%)**:
#
# ```
# BB_score = {
#     价格 > 上轨:          -20 (超买警告)
#     价格 > 中轨且带宽扩张: +20 (突破)
#     价格 > 中轨:          +10
#     价格 < 中轨:          -10
#     价格 < 下轨:          +15 (超卖)
#     带宽 < 5%:            ±0 (收窄待突破)
# }
# ```
#
# **5. 成交量得分 (VOL_score, 权重12%)**:
#
# ```
# VOL_score = {
#     量价齐升(价涨量增50%+): +30
#     价涨量增:              +15
#     价涨量缩:              +5 (缩量上涨)
#     价跌量增:              -20 (恐慌出逃)
#     价跌量缩:              -5 (惜售)
#     地量(低于20日均量50%): +10 (可能见底)
# }
# ```
#
# **6-8. KDJ/ADX/MFI得分**: 类似逻辑，根据超买超卖区间和趋势方向计算。

# %% [markdown]
# #### 1.4.2 三周期综合得分公式
#
# ```
# 周期得分 = Σ(指标原始得分 × 指标权重)
#
# 短期得分(S) = 40日数据计算的加权得分
# 中期得分(M) = 120日数据计算的加权得分
# 长期得分(L) = 240日数据计算的加权得分
#
# 综合得分 = S × 0.20 + M × 0.30 + L × 0.50
# ```
#
# **📝 完整计算示例** (2024年1月15日，上证指数):
#
# ```
# 原始数据:
# - 收盘价: 2887点
# - MA5=2895, MA10=2920, MA20=2950, MA60=3020, MA120=3080, MA250=3150
# - MACD: DIF=-18, DEA=-12, 柱状图=-6(绿柱缩小)
# - RSI14=35
# - 成交量: 较20日均量+15%
#
# 短期(40日)各指标得分:
# | 指标 | 权重 | 得分 | 说明 |
# |------|------|------|------|
# | MA   | 20%  | -50  | 空头排列(-40)+价格<MA60(-10) |
# | MACD | 18%  | -25  | DIF<0且<DEA(-30)+绿柱缩小(+5) |
# | RSI  | 12%  | +5   | RSI14=35在30-50区间 |
# | BB   | 12%  | -15  | 价格在中轨下方 |
# | VOL  | 12%  | -5   | 价跌量增 |
# | KDJ  | 10%  | +10  | K=28,D=32,超卖区 |
# | ADX  | 8%   | +15  | ADX=32,趋势明确 |
# | MFI  | 8%   | -10  | 资金流出 |
#
# 短期得分 = -50×0.20 + (-25)×0.18 + 5×0.12 + (-15)×0.12
#          + (-5)×0.12 + 10×0.10 + 15×0.08 + (-10)×0.08
#          = -10 - 4.5 + 0.6 - 1.8 - 0.6 + 1.0 + 1.2 - 0.8
#          = -14.9 (短期看空)
#
# 中期得分(类似计算) = -28.5 (中期看空)
# 长期得分(类似计算) = -35.2 (长期看空)
#
# 综合得分 = (-14.9) × 0.20 + (-28.5) × 0.30 + (-35.2) × 0.50
#          = -2.98 - 8.55 - 17.6
#          = -29.1
#
# → 判定: 熊市反弹 (长期<-30附近, 中期<-20)
# → 建议仓位: 10-30%
# ```

# %% [markdown]
# #### 1.4.3 A股特色指标计算公式
#
# **1. 北向资金得分 (North_score)**
#
# ```
# 日净买入得分 = {
#     净买入 > 80亿:  +30 (大幅流入)
#     净买入 > 30亿:  +15 (流入)
#     净买入 > 0:     +5
#     净流出 < -30亿: -15 (流出)
#     净流出 < -80亿: -30 (大幅流出)
# }
#
# 5日累计得分 = {
#     累计 > 150亿:   +40 (持续大幅流入)
#     累计 > 80亿:    +25
#     累计 > 50亿:    +15
#     累计 < -50亿:   -15
#     累计 < -100亿:  -30
# }
#
# North_score = 日净买入得分 + 5日累计得分
# ```
#
# **📝 数值示例**:
# ```
# 假设: 今日净买入+52亿, 5日累计+180亿
# → 日净买入得分: 52亿 > 30亿 → +15分
# → 5日累计得分: 180亿 > 150亿 → +40分
# → North_score = 15 + 40 = +55
# ```
#
# **2. 融资融券得分 (Margin_score)**
#
# ```
# 融资变化率得分 = {
#     日变化率 > 2%:   +30 (杠杆增加)
#     日变化率 > 1%:   +15
#     日变化率 > 0.5%: +5
#     日变化率 < -0.5%: -10
#     日变化率 < -1%:  -20
#     日变化率 < -2%:  -35 (去杠杆)
# }
#
# 融资余额水平 = {
#     余额 > 历史80%分位: -10 (杠杆过高风险)
#     余额 < 历史20%分位: +10 (杠杆低位机会)
# }
#
# Margin_score = 融资变化率得分 + 融资余额水平
# ```
#
# **3. 市场宽度得分 (Breadth_score)**
#
# ```
# 涨跌停比得分 = {
#     涨停数/跌停数 > 5:  +40 (极度强势)
#     涨停数/跌停数 > 3:  +25
#     涨停数/跌停数 > 2:  +15
#     涨停数/跌停数 < 0.5: -20
#     涨停数/跌停数 < 0.3: -35 (极度弱势)
# }
#
# 涨跌家数比 = {
#     上涨/下跌 > 2:     +20
#     上涨/下跌 > 1.5:   +10
#     上涨/下跌 < 0.7:   -10
#     上涨/下跌 < 0.5:   -20
# }
#
# 均线多头占比 = {
#     站上MA20占比 > 60%: +15
#     站上MA20占比 > 40%: +5
#     站上MA20占比 < 30%: -10
#     站上MA20占比 < 20%: -20
# }
#
# Breadth_score = 涨跌停比得分 + 涨跌家数比 + 均线多头占比
# ```
#
# **📝 完整A股指标综合示例**:
# ```
# 假设当日数据:
# - 北向资金: 日净买入+25亿, 5日累计+60亿
# - 融资余额: 1.65万亿, 日变化+0.3%
# - 涨停52家, 跌停8家, 上涨2100家, 下跌2600家
# - 站上MA20: 38%
#
# North_score = 5(日净买入0~30亿) + 15(5日累计>50亿) = +20
# Margin_score = 5(变化率0.3%>0) + 0(余额中性) = +5
# Breadth_score = 25(涨跌停比6.5>3) + (-10)(涨跌比0.8<1) + 5(MA占比38%>30%) = +20
#
# A股特色综合 = 20 × 0.35 + 5 × 0.25 + 20 × 0.40
#             = 7 + 1.25 + 8 = +16.25
#
# → 信号: 中性偏多
# → 特征: 北向资金温和流入，涨停家数多但整体涨跌家数偏弱
# ```

# %% [markdown]
# #### 1.4.4 市场状态判断算法
#
# **状态判断流程**:
#
# ```python
# def determine_market_state(L, M, S):
#     """
#     L: 长期得分 (-100 ~ +100)
#     M: 中期得分 (-100 ~ +100)
#     S: 短期得分 (-100 ~ +100)
#     """
#     # 牛市系列 (长期>30)
#     if L > 30:
#         if M > 20 and S > 10:
#             return "牛市确认(共振)", "80-100%"
#         elif M > 20:
#             return "牛市确认", "70-90%"
#         elif M > 0:
#             return "牛市震荡", "50-70%"
#         elif S < -20:
#             return "牛市短期调整", "40-60%"
#         else:
#             return "牛市中期调整", "30-50%"
#
#     # 熊市系列 (长期<-30)
#     elif L < -30:
#         if M < -20 and S < -10:
#             return "熊市确认(共振)", "0-10%"
#         elif M < -20:
#             return "熊市确认", "0-20%"
#         elif M < 0:
#             return "熊市反弹", "10-30%"
#         elif S > 20:
#             return "熊市技术反弹", "20-40%"
#         else:
#             return "熊市筑底", "20-40%"
#
#     # 震荡系列 (-30 <= 长期 <= 30)
#     else:
#         if M > 10 and S > 10:
#             return "突破在即", "50-70%"
#         elif M < -10 and S < -10:
#             return "破位风险", "10-30%"
#         elif S > 20 and M > 0:
#             return "复苏初期", "40-60%"
#         elif S < -20 and M < 0:
#             return "见顶回落", "20-40%"
#         else:
#             return "窄幅震荡", "30-50%"
# ```
#
# **📝 判断示例**:
#
# | 日期 | 长期(L) | 中期(M) | 短期(S) | 状态 | 仓位 |
# |------|---------|---------|---------|------|------|
# | 2015-06-01 | +55 | +48 | +62 | 牛市确认(共振) | 80-100% |
# | 2015-07-15 | +35 | -25 | -55 | 牛市中期调整 | 30-50% |
# | 2018-10-15 | -45 | -38 | -28 | 熊市确认(共振) | 0-10% |
# | 2019-01-05 | -35 | +5 | +25 | 熊市技术反弹 | 20-40% |
# | 2020-03-25 | -8 | +15 | +32 | 复苏初期 | 40-60% |
# | 2023-08-01 | +12 | -5 | -28 | 见顶回落 | 20-40% |

# %% [markdown]
# #### 1.4.5 验证准确率定义
#
# **1. 信号方向准确率**:
#
# ```
# 对于看多信号(综合得分 > +30):
#   正确条件 = 后续N日收益率 > 0
#
# 对于看空信号(综合得分 < -30):
#   正确条件 = 后续N日收益率 < 0
#
# 对于中性信号(-30 <= 综合得分 <= +30):
#   正确条件 = |后续N日收益率| < 2%
#
# 准确率 = 正确信号数 / 总信号数 × 100%
# ```
#
# **2. 三周期分别验证**:
#
# | 周期 | 验证期限 | 目标准确率 | 说明 |
# |------|----------|------------|------|
# | 短期 | 5个交易日 | >55% | 高频但噪音多 |
# | 中期 | 20个交易日 | >60% | 主要决策依据 |
# | 长期 | 60个交易日 | >65% | 最可靠信号 |
#
# **3. 市场状态识别准确率**:
#
# ```
# 牛市状态(含共振/确认/震荡/调整):
#   正确条件 = 后续60日最大收益 > 5%
#
# 熊市状态(含共振/确认/反弹/筑底):
#   正确条件 = 后续60日最大回撤 > 5%
#
# 震荡状态:
#   正确条件 = 后续60日振幅在±8%以内
# ```
#
# **4. 分市场周期验证标准**:
#
# | 市场周期 | 时间段 | 特征 | 重点验证 |
# |----------|--------|------|----------|
# | 2015牛熊 | 2015.01-2016.01 | 暴涨暴跌 | 反转信号捕捉 |
# | 慢熊调整 | 2018.01-2019.01 | 持续阴跌 | 熊市识别准确性 |
# | 疫情冲击 | 2020.01-2020.04 | V型反转 | 底部信号灵敏度 |
# | 结构行情 | 2021.01-2023.12 | 分化严重 | 震荡期仓位控制 |

# %% [markdown]
# ---
#
# ## 2. 数据源与可用性
#
# ### 2.1 JQData 数据范围
#
# | 数据类型 | API | 起始日期 | 结束日期 | 说明 |
# |----------|-----|----------|----------|------|
# | 指数价格 | `get_price` | 2005年 | 至今 | 完全覆盖 |
# | 北向资金(买卖分项) | `STK_ML_QUOTA` | 2014-11-17 | 2024-08-16 | 之后仅有成交总额 |
# | 融资融券 | `STK_MT_TOTAL` | 2010年 | 至今 | 完全覆盖 |
# | 涨跌停 | `get_price` + `high_limit/low_limit` | 2005年 | 至今 | 完全覆盖 |
#
# ### 2.2 回测时间范围选择
#
# 基于数据可用性，选择以下回测区间：
#
# - **Phase 1 (快速验证)**: 2023-01-01 ~ 2024-08-16 (约1.5年)
# - **Phase 2 (完整回测)**: 2014-11-17 ~ 2024-08-16 (约10年)

# %% [markdown]
# ---
#
# ## 3. 市场状态量化定义
#
# ### 3.1 14种市场状态
#
# 基于短中长三周期得分，定义14种市场状态：
#
# #### 🟢 牛市系列 (5种)
#
# | 状态 | 长期得分 | 中期得分 | 短期得分 | 建议仓位 | 说明 |
# |------|----------|----------|----------|----------|------|
# | 牛市确认(共振) | >30 | >20 | >10 | 80-100% | 全周期共振看多 |
# | 牛市确认 | >30 | >20 | 任意 | 70-90% | 长中期看多 |
# | 牛市震荡 | >30 | 0~20 | 任意 | 50-70% | 牛市中的整理 |
# | 牛市短期调整 | >30 | 任意 | <-20 | 40-60% | 短期回调，可逢低 |
# | 牛市中期调整 | >30 | <0 | 任意 | 30-50% | 中期调整，谨慎 |
#
# #### 🔴 熊市系列 (5种)
#
# | 状态 | 长期得分 | 中期得分 | 短期得分 | 建议仓位 | 说明 |
# |------|----------|----------|----------|----------|------|
# | 熊市确认(共振) | <-30 | <-20 | <-10 | 0-10% | 全周期共振看空 |
# | 熊市确认 | <-30 | <-20 | 任意 | 0-20% | 长中期看空 |
# | 熊市反弹 | <-30 | -20~0 | 任意 | 10-30% | 反弹持续性存疑 |
# | 熊市技术反弹 | <-30 | 任意 | >20 | 20-40% | 短线可参与 |
# | 熊市筑底 | <-30 | >0 | 任意 | 20-40% | 可能出现转机 |
#
# #### 🟡 震荡系列 (4种)
#
# | 状态 | 长期得分 | 中期得分 | 短期得分 | 建议仓位 | 说明 |
# |------|----------|----------|----------|----------|------|
# | 突破在即 | -30~30 | >10 | >10 | 50-70% | 震荡上沿 |
# | 破位风险 | -30~30 | <-10 | <-10 | 10-30% | 震荡下沿 |
# | 复苏初期 | -30~30 | >0 | >20 | 40-60% | 短期走强 |
# | 见顶回落 | -30~30 | <0 | <-20 | 20-40% | 减仓观望 |

# %% [markdown]
# ### 3.2 A股特色指标阈值
#
# | 指标 | 强看多 | 看多 | 中性 | 看空 | 强看空 |
# |------|--------|------|------|------|--------|
# | 北向5日累计(亿) | >100 | 50~100 | -50~50 | -100~-50 | <-100 |
# | 融资变化率(%) | >2% | 1%~2% | -1%~1% | -2%~-1% | <-2% |
# | 涨跌停比 | >3 | 2~3 | 0.5~2 | 0.3~0.5 | <0.3 |

# %% [markdown]
# ---
#
# ## 4. Phase 1: 快速验证回测
#
# ### 4.1 回测参数
#
# | 参数 | 值 | 说明 |
# |------|-----|------|
# | 时间范围 | 2023-01-01 ~ 2024-08-16 | 约1.5年 |
# | 采样间隔 | 每10个交易日 | ~40个数据点 |
# | 预计耗时 | 2-3分钟 | |
# | 目的 | 验证框架正确性 | |

# %%
# Phase 1: 快速验证回测
print("\n" + "="*60)
print("📊 Phase 1: 快速验证回测")
print("="*60)

try:
    from core.signal_backtest import run_phase1_backtest, SignalBacktester
    from core.backtest_visualization import BacktestVisualization
    
    print("\n回测参数:")
    print("  - 时间范围: 2023-01-01 ~ 2024-08-16 (约1.5年)")
    print("  - 采样间隔: 每10个交易日")
    print("  - 目的: 快速验证框架正确性")
    print("\n正在执行Phase 1回测...")
    
    phase1_result = run_phase1_backtest(sample_interval=10)
    
    print(f"\n✅ Phase 1 回测完成!")
    print(f"   总信号数: {phase1_result.total_signals}")
    print(f"   短期准确率: {phase1_result.short_accuracy_5d:.1f}%")
    print(f"   中期准确率: {phase1_result.medium_accuracy_20d:.1f}%")
    print(f"   长期准确率: {phase1_result.long_accuracy_60d:.1f}%")
    
except Exception as e:
    print(f"❌ Phase 1 回测失败: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ============================================================
# 📊 Phase 1: 快速验证回测
# ============================================================
#
# 回测参数:
#   - 时间范围: 2023-01-01 ~ 2024-08-16 (约1.5年)
#   - 采样间隔: 每10个交易日
#   - 目的: 快速验证框架正确性
#
# 正在执行Phase 1回测...
# 2026-01-03 13:23:09,160 - INFO - JQData认证成功
# 2026-01-03 13:23:09,162 - INFO - TrendAnalyzer (8维指标) 初始化成功
# 2026-01-03 13:23:09,166 - INFO - SimpleHMM 初始化成功
# 2026-01-03 13:23:09,170 - INFO - IBDStyleAnalyzer 初始化成功
# 2026-01-03 13:23:09,170 - INFO - 开始回测: 2023-01-01 ~ 2024-08-16
# auth success
# 2026-01-03 13:23:09,839 - INFO - 共 394 个交易日
# 2026-01-03 13:23:10,210 - INFO - 采样 40 个交易日进行回测
# 2026-01-03 13:23:10,210 - INFO - 回测进度: 1/40 (2023-01-03)
# 2026-01-03 13:23:14,219 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-17.3, 阶段=窄幅震荡
# 2026-01-03 13:23:14,434 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:14,437 - INFO - 🚀 正在初始化数据源管理器...
# 2026-01-03 13:23:14,439 - INFO - 加载配置成功: jqdata_config.json
# 2026-01-03 13:23:14,439 - INFO - 聚宽认证成功: 13327806797
# 2026-01-03 13:23:14,439 - INFO - 正在检测账号数据权限...
# 2026-01-03 13:23:14,676 - INFO - ✅ 通过 get_account_info() 检测到账号权限: 数据模式: 实时, 范围: 2005-01-01 至 2026-01-03
# 2026-01-03 13:23:14,677 - INFO - ✅ JQData已连接: premium (2005-01-01 ~ 2026-01-03)
# /home/taotao/dev/QuantTest/TRQuant/venv/lib/python3.12/site-packages/py_mini_racer/py_mini_racer.py:15: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2026-01-03 13:23:14,988 - INFO - ✅ AKShare可用
# 2026-01-03 13:23:14,988 - INFO - ℹ️ baostock未安装（可选）
# 2026-01-03 13:23:15,038 - INFO - ✅ 本地缓存(MongoDB)可用
# 2026-01-03 13:23:15,038 - INFO - ==================================================
# 2026-01-03 13:23:15,039 - INFO - 📊 数据源状态汇总:
# 2026-01-03 13:23:15,039 - INFO -    ✅ jqdata: premium
# 2026-01-03 13:23:15,039 - INFO -    ✅ akshare: standard
# 2026-01-03 13:23:15,039 - INFO -    ❌ baostock: baostock未安装
# 2026-01-03 13:23:15,040 - INFO -    ✅ local_cache: standard
# 2026-01-03 13:23:15,040 - INFO - ==================================================
# 2026-01-03 13:23:15,250 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:15,254 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:17,640 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=42.2, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:23:17,857 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:18,078 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:18,082 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:20,362 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=18.8, 阶段=宽幅震荡
# 2026-01-03 13:23:20,579 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:20,805 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:20,809 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:22,795 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=22.0, 阶段=突破在即
# 2026-01-03 13:23:23,010 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:23,220 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:23,223 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:25,329 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=3.2, 阶段=窄幅震荡
# 2026-01-03 13:23:25,545 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:25,755 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:25,759 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:27,730 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-15.7, 阶段=破位风险
# 2026-01-03 13:23:27,946 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:28,158 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:28,161 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:30,119 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=23.8, 阶段=复苏初期
# 2026-01-03 13:23:30,335 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:30,559 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:30,563 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:32,336 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=37.7, 阶段=突破在即
# 2026-01-03 13:23:32,551 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:32,762 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:32,766 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:34,717 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=39.5, 阶段=突破在即
# 2026-01-03 13:23:34,934 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:35,150 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:35,154 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:36,923 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-16.6, 阶段=宽幅震荡
# 2026-01-03 13:23:37,138 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:37,368 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:37,372 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:39,225 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-20.6, 阶段=宽幅震荡
# 2026-01-03 13:23:39,471 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:39,681 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:39,685 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:41,513 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=22.4, 阶段=突破在即
# 2026-01-03 13:23:41,728 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:41,940 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:41,943 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:43,760 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=4.2, 阶段=复苏初期
# 2026-01-03 13:23:44,016 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:44,228 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:44,231 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:45,847 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-27.8, 阶段=破位风险
# 2026-01-03 13:23:46,062 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:46,273 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:46,277 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:47,875 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=11.2, 阶段=复苏初期
# 2026-01-03 13:23:48,093 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:48,307 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:48,311 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:49,953 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-49.8, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:23:50,171 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:50,411 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:50,414 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:52,000 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-34.5, 阶段=熊市确认
# 2026-01-03 13:23:52,215 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:52,426 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:52,429 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:54,034 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-18.3, 阶段=破位风险
# 2026-01-03 13:23:54,250 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:54,462 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:54,466 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:56,121 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-27.0, 阶段=破位风险
# 2026-01-03 13:23:56,337 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:56,547 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:56,550 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:23:58,145 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-52.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:23:58,361 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:23:58,571 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:23:58,574 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:00,270 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-23.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:24:00,486 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:00,696 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:00,699 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:02,274 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=2.5, 阶段=复苏初期
# 2026-01-03 13:24:02,490 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:02,701 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:02,705 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:04,289 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-40.3, 阶段=破位风险
# 2026-01-03 13:24:04,553 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:04,769 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:04,773 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:06,362 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-55.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:24:06,578 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:06,788 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:06,792 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:08,361 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-13.1, 阶段=熊市反弹
# 2026-01-03 13:24:08,576 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:08,786 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:08,790 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:10,492 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-59.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:24:10,707 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:10,923 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:10,926 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:12,514 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-4.0, 阶段=复苏初期
# 2026-01-03 13:24:12,728 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:12,955 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:12,959 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:14,585 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=12.8, 阶段=复苏初期
# 2026-01-03 13:24:14,814 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:15,024 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:15,028 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:16,701 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=26.6, 阶段=突破在即
# 2026-01-03 13:24:16,917 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:17,131 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:17,134 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:18,755 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=39.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:19,011 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:19,226 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:19,230 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:20,803 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=17.1, 阶段=宽幅震荡
# 2026-01-03 13:24:21,019 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:21,231 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:21,234 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:22,844 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=24.6, 阶段=突破在即
# 2026-01-03 13:24:23,060 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:23,271 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:23,275 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:24,957 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=49.7, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:25,173 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:25,383 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:25,387 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:26,978 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=49.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:27,192 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:27,405 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:27,409 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:29,057 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-46.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:24:29,271 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:29,488 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:29,492 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:31,020 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-28.1, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:24:31,237 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:31,455 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:31,459 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:32,934 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-27.2, 阶段=熊市确认
# 2026-01-03 13:24:33,149 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:33,371 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:33,374 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:34,890 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=9.8, 阶段=复苏初期
# 2026-01-03 13:24:35,119 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:35,330 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:35,333 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:36,705 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-52.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:24:36,919 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:37,129 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:37,133 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:38,504 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-38.9, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:24:38,719 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:38,953 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:38,956 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:38,957 - INFO - 回测完成: 共40个信号, 5日准确率=65.0%, 耗时=90.4秒
# ✅ Phase 1 回测完成!
#    总信号数: 40
#    短期准确率: 57.5%
#    中期准确率: 80.0%
#    长期准确率: 65.0%

# %%
# Phase 1 结果报告
if 'phase1_result' in dir() and phase1_result:
    backtester = SignalBacktester()
    report = backtester.generate_report(phase1_result)
    display(Markdown(report))
# Out:
# # 市场趋势信号回测报告 (增强版)
#
# ## 回测概况
#
# | 项目 | 值 |
# |------|-----|
# | 回测时间 | 2026-01-03 13:23:08 |
# | 回测区间 | 2023-01-01 ~ 2024-08-16 |
# | 基准指数 | 000001.XSHG |
# | 总信号数 | 40 |
# | 看多信号 | 10 |
# | 看空信号 | 11 |
# | 中性信号 | 19 |
# | 耗时 | 90.4秒 |
#
# ## 综合准确率
#
# | 持有期 | 准确率 |
# |--------|--------|
# | 5日 | 65.0% |
# | 10日 | 75.0% |
# | 20日 | 75.0% |
# | 60日 | 67.5% |
#
# ## 分周期准确率
#
# | 周期 | 验证期 | 准确率 | 看多准确 | 看空准确 |
# |------|--------|--------|----------|----------|
# | 短期 | 5日 | 57.5% | 35.0% | 100.0% |
# | 中期 | 20日 | 80.0% | 44.4% | 77.8% |
# | 长期 | 60日 | 65.0% | 25.0% | 64.3% |
#
# ## 市场状态准确率
#
# | 状态类别 | 60日准确率 |
# |----------|------------|
# | 牛市系列 | 0.0% |
# | 熊市系列 | 21.4% |
# | 震荡系列 | 64.3% |
# | **综合** | **30.0%** |
#
# ## 分类信号表现
#
# ### 看多信号
# | 指标 | 值 |
# |------|-----|
# | 信号数量 | 10 |
# | 5日胜率 | 40.0% |
# | 5日平均收益 | -0.73% |
# | 20日平均收益 | -0.99% |
#
# ### 看空信号
# | 指标 | 值 |
# |------|-----|
# | 信号数量 | 11 |
# | 5日胜率 | 81.8% |
# | 5日平均收益 | -1.02% |
# | 20日平均收益 | -1.71% |
#
# ## 年度统计
#
# | 年份 | 信号数 | 5日准确 | 20日准确 | 60日准确 | 短期准确 | 中期准确 | 长期准确 |
# |------|--------|---------|----------|----------|----------|----------|----------|
# | 2023 | 25 | 64% | 80% | 76% | 60% | 88% | 72% |
# | 2024 | 15 | 67% | 67% | 53% | 53% | 67% | 53% |

# %% [markdown]
# ---
#
# ## 5. Phase 2: 完整10年回测
#
# ### 5.1 回测参数
#
# | 参数 | 值 | 说明 |
# |------|-----|------|
# | 时间范围 | 2014-11-17 ~ 2024-08-16 | 约10年 |
# | 采样间隔 | 每10个交易日 | ~240个数据点 |
# | 预计耗时 | 8-12分钟 | 分3段串行 |
#
# ### 5.2 时间分割 (市场特征)
#
# | 时间段 | 数据点 | 市场特征 |
# |--------|--------|----------|
# | 2014.11-2017.12 | ~250 | 牛熊转换期(2015股灾) |
# | 2018.01-2021.06 | ~280 | 熊市+疫情复苏 |
# | 2021.07-2024.08 | ~250 | 结构性行情 |

# %%
# Phase 2: 完整10年回测
# ⚠️ 注意: 此cell执行时间较长 (约8-12分钟)

RUN_PHASE2 = True  # 设为True执行完整回测

if not RUN_PHASE2:
    print("⚠️ Phase 2 未启用")
    print("如需执行完整10年回测，请将 RUN_PHASE2 改为 True")
else:
    print("\n" + "="*60)
    print("📊 Phase 2: 完整10年回测")
    print("="*60)
    
    try:
        from core.signal_backtest import run_phase2_backtest
        
        print("\n回测参数:")
        print("  - 时间范围: 2014-11-17 ~ 2024-08-16 (约10年)")
        print("  - 采样间隔: 每10个交易日")
        print("  - 分3个时间段串行处理")
        print("\n正在执行Phase 2完整回测...")
        print("预计耗时: 8-12分钟\n")
        
        phase2_result = run_phase2_backtest(sample_interval=10)
        
        print(f"\n✅ Phase 2 完整回测完成!")
        print(f"   总信号数: {phase2_result.total_signals}")
        print(f"   短期准确率: {phase2_result.short_accuracy_5d:.1f}%")
        print(f"   中期准确率: {phase2_result.medium_accuracy_20d:.1f}%")
        print(f"   长期准确率: {phase2_result.long_accuracy_60d:.1f}%")
        print(f"   市场状态准确率: {phase2_result.state_accuracy_60d:.1f}%")
        
    except Exception as e:
        print(f"❌ Phase 2 回测失败: {e}")
        import traceback
        traceback.print_exc()
# Out:
# 2026-01-03 13:24:38,972 - INFO - 开始Phase 2完整回测 (使用3个进程)
# 2026-01-03 13:24:38,972 - INFO - Worker 1: 回测 2014-11-17 ~ 2017-12-31
# 2026-01-03 13:24:38,973 - INFO - JQData认证成功
# 2026-01-03 13:24:38,973 - INFO - TrendAnalyzer (8维指标) 初始化成功
# 2026-01-03 13:24:38,973 - INFO - SimpleHMM 初始化成功
# 2026-01-03 13:24:38,973 - INFO - IBDStyleAnalyzer 初始化成功
# 2026-01-03 13:24:38,974 - INFO - 开始回测: 2014-11-17 ~ 2017-12-31
# ============================================================
# 📊 Phase 2: 完整10年回测
# ============================================================
#
# 回测参数:
#   - 时间范围: 2014-11-17 ~ 2024-08-16 (约10年)
#   - 采样间隔: 每10个交易日
#   - 分3个时间段串行处理
#
# 正在执行Phase 2完整回测...
# 预计耗时: 8-12分钟
# 2026-01-03 13:24:39,207 - INFO - 共 765 个交易日
# 2026-01-03 13:24:39,428 - INFO - 采样 77 个交易日进行回测
# 2026-01-03 13:24:39,428 - INFO - 回测进度: 1/77 (2014-11-17)
# 2026-01-03 13:24:40,837 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=38.8, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:41,050 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:41,261 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:41,264 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:42,431 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=40.8, 阶段=突破在即
# 2026-01-03 13:24:42,647 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:42,858 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:42,862 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:44,025 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=39.8, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:44,240 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:44,456 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:44,460 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:45,672 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=36.0, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:45,888 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:46,099 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:46,103 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:47,259 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=9.7, 阶段=窄幅震荡
# 2026-01-03 13:24:47,475 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:47,687 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:47,691 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:48,872 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-7.6, 阶段=窄幅震荡
# 2026-01-03 13:24:49,089 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:49,301 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:49,304 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:50,596 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-20.9, 阶段=破位风险
# 2026-01-03 13:24:50,842 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:51,054 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:51,058 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:52,415 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=19.9, 阶段=复苏初期
# 2026-01-03 13:24:52,630 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:52,840 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:52,843 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:54,189 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=47.0, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:54,404 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:54,616 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:54,619 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:55,836 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=36.8, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:56,050 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:56,265 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:56,269 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:57,422 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=44.9, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:24:57,636 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:57,847 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:57,850 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:24:59,196 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=28.5, 阶段=突破在即
# 2026-01-03 13:24:59,411 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:24:59,621 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:24:59,625 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:00,986 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-14.0, 阶段=破位风险
# 2026-01-03 13:25:01,201 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:01,430 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:01,433 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:02,600 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=31.4, 阶段=突破在即
# 2026-01-03 13:25:02,823 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:03,033 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:03,036 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:04,418 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=34.5, 阶段=突破在即
# 2026-01-03 13:25:04,667 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:04,877 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:04,880 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:06,230 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-48.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:25:06,455 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:06,672 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:06,675 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:07,820 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-22.9, 阶段=宽幅震荡
# 2026-01-03 13:25:08,064 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:08,274 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:08,278 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:09,476 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-31.4, 阶段=熊市确认
# 2026-01-03 13:25:09,691 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:09,906 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:09,910 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:11,139 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-3.1, 阶段=复苏初期
# 2026-01-03 13:25:11,355 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:11,568 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:11,572 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:12,742 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-46.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:25:12,956 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:13,167 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:13,171 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:14,359 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-30.6, 阶段=熊市反弹
# 2026-01-03 13:25:14,586 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:14,820 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:14,823 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:16,012 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-21.7, 阶段=宽幅震荡
# 2026-01-03 13:25:16,227 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:16,437 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:16,441 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:17,655 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=25.5, 阶段=突破在即
# 2026-01-03 13:25:17,888 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:18,101 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:18,104 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:19,263 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=12.7, 阶段=宽幅震荡
# 2026-01-03 13:25:19,478 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:19,690 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:19,694 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:22,280 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=37.1, 阶段=突破在即
# 2026-01-03 13:25:22,508 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:22,719 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:22,722 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:23,879 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=28.7, 阶段=突破在即
# 2026-01-03 13:25:24,094 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:24,304 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:24,308 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:25,536 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-28.0, 阶段=破位风险
# 2026-01-03 13:25:25,791 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:26,002 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:26,006 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:27,155 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=48.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:25:27,373 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:27,584 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:27,587 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:28,736 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-46.8, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:25:28,951 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:29,164 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:29,168 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:30,394 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-42.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:25:30,609 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:30,819 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:30,822 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:32,006 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-31.4, 阶段=熊市确认
# 2026-01-03 13:25:32,225 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:32,436 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:32,439 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:33,612 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-16.5, 阶段=窄幅震荡
# 2026-01-03 13:25:33,828 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:34,045 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:34,048 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:35,530 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-16.2, 阶段=宽幅震荡
# 2026-01-03 13:25:35,806 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:36,028 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:36,032 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:37,250 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=9.0, 阶段=复苏初期
# 2026-01-03 13:25:37,467 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:37,678 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:37,681 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:38,856 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=15.2, 阶段=宽幅震荡
# 2026-01-03 13:25:39,072 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:39,293 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:39,297 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:40,477 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-27.0, 阶段=破位风险
# 2026-01-03 13:25:40,693 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:40,906 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:40,909 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:42,084 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-57.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:25:42,299 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:42,509 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:42,512 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:43,682 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-28.1, 阶段=熊市确认
# 2026-01-03 13:25:43,899 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:44,130 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:44,134 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:45,426 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=30.7, 阶段=突破在即
# 2026-01-03 13:25:45,660 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:45,871 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:45,875 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:47,069 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=21.5, 阶段=突破在即
# 2026-01-03 13:25:47,284 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:47,496 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:47,499 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:48,665 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=39.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:25:48,894 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:49,109 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:49,112 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:50,303 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=21.3, 阶段=宽幅震荡
# 2026-01-03 13:25:50,518 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:50,729 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:50,733 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:51,913 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-29.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:25:52,130 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:52,342 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:52,346 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:53,504 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=41.1, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:25:53,737 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:53,948 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:53,952 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:55,218 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=16.4, 阶段=突破在即
# 2026-01-03 13:25:55,433 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:55,661 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:55,664 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:56,878 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-39.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:25:57,103 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:57,313 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:57,317 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:25:58,495 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-30.6, 阶段=破位风险
# 2026-01-03 13:25:58,712 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:25:58,926 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:25:58,929 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:00,797 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=40.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:26:01,089 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:01,413 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:01,416 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:03,040 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=34.9, 阶段=突破在即
# 2026-01-03 13:26:03,355 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:03,638 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:03,642 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:05,505 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=24.2, 阶段=突破在即
# 2026-01-03 13:26:05,785 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:06,142 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:06,145 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:06,146 - INFO - 回测进度: 51/77 (2016-12-02)
# 2026-01-03 13:26:07,918 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=21.6, 阶段=突破在即
# 2026-01-03 13:26:08,265 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:08,612 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:08,616 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:10,564 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-41.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:10,880 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:11,098 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:11,101 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:12,278 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-42.1, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:12,494 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:12,704 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:12,708 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:13,865 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-55.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:14,081 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:14,292 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:14,296 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:15,840 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=12.9, 阶段=复苏初期
# 2026-01-03 13:26:16,057 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:16,267 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:16,271 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:17,686 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=45.4, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:26:17,903 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:18,114 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:18,117 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:19,501 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=8.6, 阶段=窄幅震荡
# 2026-01-03 13:26:19,736 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:19,947 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:19,951 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:21,405 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=25.8, 阶段=突破在即
# 2026-01-03 13:26:21,620 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:21,831 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:21,834 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:23,214 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=19.7, 阶段=突破在即
# 2026-01-03 13:26:23,429 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:23,639 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:23,643 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:24,998 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-45.6, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:25,213 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:25,460 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:25,463 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:30,130 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-45.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:30,347 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:30,569 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:30,572 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:31,933 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-24.9, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:32,147 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:32,358 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:32,362 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:33,716 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-10.6, 阶段=窄幅震荡
# 2026-01-03 13:26:33,932 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:34,142 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:34,146 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:35,610 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=11.8, 阶段=复苏初期
# 2026-01-03 13:26:35,832 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:36,072 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:36,075 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:37,434 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=37.1, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:26:37,649 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:37,858 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:37,862 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:39,233 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-8.0, 阶段=见顶回落
# 2026-01-03 13:26:39,449 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:39,661 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:39,664 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:41,122 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=45.7, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:26:41,337 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:41,550 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:41,554 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:42,922 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-22.1, 阶段=破位风险
# 2026-01-03 13:26:43,136 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:43,347 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:43,350 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:44,728 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=40.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:26:44,973 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:45,184 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:45,188 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:46,571 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=25.3, 阶段=突破在即
# 2026-01-03 13:26:46,785 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:46,996 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:46,999 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:48,382 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-32.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:48,599 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:48,813 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:48,817 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:50,231 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=14.9, 阶段=复苏初期
# 2026-01-03 13:26:50,448 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:50,681 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:50,685 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:52,220 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=19.5, 阶段=复苏初期
# 2026-01-03 13:26:52,436 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:52,650 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:52,653 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:54,021 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=44.1, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:26:54,236 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:54,447 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:54,450 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:55,943 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-33.1, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:56,159 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:56,370 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:56,373 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:57,732 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-35.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:57,948 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:58,159 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:58,163 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:59,524 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-41.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:26:59,746 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:26:59,963 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:26:59,966 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:26:59,968 - INFO - 回测完成: 共77个信号, 5日准确率=58.4%, 耗时=141.0秒
# 2026-01-03 13:26:59,968 - INFO - Worker 2: 回测 2018-01-01 ~ 2021-06-30
# 2026-01-03 13:26:59,969 - INFO - JQData认证成功
# 2026-01-03 13:26:59,969 - INFO - TrendAnalyzer (8维指标) 初始化成功
# 2026-01-03 13:26:59,969 - INFO - SimpleHMM 初始化成功
# 2026-01-03 13:26:59,969 - INFO - IBDStyleAnalyzer 初始化成功
# 2026-01-03 13:26:59,969 - INFO - 开始回测: 2018-01-01 ~ 2021-06-30
# 2026-01-03 13:27:00,215 - INFO - 共 848 个交易日
# 2026-01-03 13:27:00,500 - INFO - 采样 85 个交易日进行回测
# 2026-01-03 13:27:00,500 - INFO - 回测进度: 1/85 (2018-01-02)
# 2026-01-03 13:27:01,868 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=25.6, 阶段=突破在即
# 2026-01-03 13:27:02,087 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:02,300 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:02,304 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:03,695 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=36.9, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:27:03,911 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:04,121 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:04,124 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:05,497 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=25.5, 阶段=宽幅震荡
# 2026-01-03 13:27:05,772 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:05,982 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:05,985 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:07,353 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-51.8, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:07,598 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:07,809 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:07,812 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:09,175 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-20.9, 阶段=熊市反弹
# 2026-01-03 13:27:09,390 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:09,601 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:09,605 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:11,009 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-7.1, 阶段=宽幅震荡
# 2026-01-03 13:27:11,225 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:11,435 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:11,439 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:12,796 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-49.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:13,015 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:13,228 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:13,231 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:14,605 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-43.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:14,840 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:15,068 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:15,071 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:16,658 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-2.4, 阶段=宽幅震荡
# 2026-01-03 13:27:16,873 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:17,085 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:17,088 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:18,453 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=34.7, 阶段=突破在即
# 2026-01-03 13:27:18,669 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:18,880 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:18,884 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:20,277 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-42.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:20,583 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:20,794 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:20,798 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:22,178 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-53.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:22,398 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:22,609 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:22,613 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:23,979 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-47.6, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:24,195 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:24,405 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:24,409 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:25,613 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-39.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:25,828 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:26,039 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:26,043 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:27,205 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=7.9, 阶段=复苏初期
# 2026-01-03 13:27:27,420 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:27,630 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:27,633 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:28,789 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-17.3, 阶段=破位风险
# 2026-01-03 13:27:29,005 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:29,216 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:29,219 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:30,412 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-4.7, 阶段=窄幅震荡
# 2026-01-03 13:27:30,627 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:30,838 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:30,842 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:32,000 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-45.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:32,216 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:32,426 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:32,429 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:33,592 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=33.9, 阶段=突破在即
# 2026-01-03 13:27:33,807 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:34,018 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:34,021 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:35,189 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-37.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:35,406 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:35,616 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:35,619 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:36,794 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-19.1, 阶段=熊市反弹
# 2026-01-03 13:27:37,010 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:37,220 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:37,224 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:38,378 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-2.4, 阶段=宽幅震荡
# 2026-01-03 13:27:38,593 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:38,803 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:38,807 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:39,966 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-27.2, 阶段=破位风险
# 2026-01-03 13:27:40,183 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:40,403 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:40,406 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:41,572 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-39.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:41,787 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:41,998 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:42,002 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:43,190 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-52.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:43,405 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:43,615 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:43,618 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:44,786 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=12.9, 阶段=复苏初期
# 2026-01-03 13:27:45,002 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:45,212 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:45,216 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:46,596 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=30.5, 阶段=突破在即
# 2026-01-03 13:27:46,812 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:47,022 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:47,025 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:48,392 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=34.0, 阶段=突破在即
# 2026-01-03 13:27:48,606 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:48,817 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:48,820 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:50,005 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=45.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:27:50,221 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:50,455 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:50,459 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:51,669 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=8.1, 阶段=窄幅震荡
# 2026-01-03 13:27:51,884 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:52,094 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:52,097 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:53,263 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=9.6, 阶段=宽幅震荡
# 2026-01-03 13:27:53,478 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:53,689 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:53,692 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:54,879 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=5.8, 阶段=窄幅震荡
# 2026-01-03 13:27:55,092 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:55,308 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:55,311 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:56,579 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-35.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:27:56,794 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:57,004 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:57,007 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:58,292 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-17.3, 阶段=宽幅震荡
# 2026-01-03 13:27:58,522 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:27:58,738 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:27:58,741 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:27:59,902 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-17.6, 阶段=熊市反弹
# 2026-01-03 13:28:00,116 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:00,326 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:00,330 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:01,693 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-12.4, 阶段=窄幅震荡
# 2026-01-03 13:28:01,908 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:02,119 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:02,122 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:03,545 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=6.3, 阶段=复苏初期
# 2026-01-03 13:28:03,761 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:03,995 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:03,998 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:05,162 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-47.6, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:28:05,377 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:05,587 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:05,591 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:06,865 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-11.8, 阶段=窄幅震荡
# 2026-01-03 13:28:07,080 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:07,290 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:07,293 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:08,453 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-45.6, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:28:08,668 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:08,879 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:08,882 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:10,046 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=5.3, 阶段=复苏初期
# 2026-01-03 13:28:10,280 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:10,533 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:10,537 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:11,905 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=33.3, 阶段=突破在即
# 2026-01-03 13:28:12,123 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:12,334 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:12,337 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:13,700 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=9.6, 阶段=窄幅震荡
# 2026-01-03 13:28:13,916 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:14,129 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:14,132 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:15,326 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=15.0, 阶段=复苏初期
# 2026-01-03 13:28:15,573 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:15,786 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:15,790 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:16,978 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=17.7, 阶段=复苏初期
# 2026-01-03 13:28:17,193 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:17,425 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:17,430 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:18,605 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-33.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:28:18,821 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:19,032 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:19,036 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:20,444 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-45.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:28:20,663 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:20,875 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:20,879 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:22,057 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-3.1, 阶段=复苏初期
# 2026-01-03 13:28:22,273 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:22,489 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:22,492 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:23,685 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=27.2, 阶段=突破在即
# 2026-01-03 13:28:23,902 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:24,127 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:24,131 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:25,329 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=50.2, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:28:25,546 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:25,793 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:25,796 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:25,797 - INFO - 回测进度: 51/85 (2020-01-21)
# 2026-01-03 13:28:26,958 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-11.5, 阶段=见顶回落
# 2026-01-03 13:28:27,174 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:27,437 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:27,440 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:28,639 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-11.1, 阶段=窄幅震荡
# 2026-01-03 13:28:28,855 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:29,075 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:29,079 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:30,447 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=19.7, 阶段=突破在即
# 2026-01-03 13:28:30,665 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:30,876 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:30,880 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:32,269 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-8.7, 阶段=宽幅震荡
# 2026-01-03 13:28:32,485 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:32,752 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:32,755 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:33,915 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-37.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:28:34,130 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:34,342 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:34,345 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:35,542 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=10.0, 阶段=复苏初期
# 2026-01-03 13:28:35,803 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:36,037 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:36,041 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:37,230 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=12.2, 阶段=复苏初期
# 2026-01-03 13:28:37,444 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:37,656 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:37,659 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:38,822 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=20.9, 阶段=突破在即
# 2026-01-03 13:28:39,039 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:39,249 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:39,253 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:40,620 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-12.8, 阶段=见顶回落
# 2026-01-03 13:28:40,836 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:41,070 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:41,074 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:42,437 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=41.1, 阶段=突破在即
# 2026-01-03 13:28:42,653 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:42,863 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:42,866 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:44,028 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=38.4, 阶段=突破在即
# 2026-01-03 13:28:44,244 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:44,455 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:44,458 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:45,738 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=50.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:28:45,957 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:46,168 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:46,171 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:47,551 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=31.4, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:28:47,781 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:47,992 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:47,996 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:49,407 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=25.8, 阶段=突破在即
# 2026-01-03 13:28:49,623 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:49,851 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:49,854 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:51,137 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=12.0, 阶段=宽幅震荡
# 2026-01-03 13:28:51,353 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:51,564 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:51,567 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:52,930 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=5.2, 阶段=宽幅震荡
# 2026-01-03 13:28:53,145 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:53,360 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:53,363 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:54,722 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-33.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:28:54,962 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:55,173 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:55,176 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:56,691 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-13.3, 阶段=窄幅震荡
# 2026-01-03 13:28:56,906 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:57,116 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:57,120 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:28:58,495 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-31.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:28:58,711 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:28:58,922 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:28:58,925 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:00,118 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=10.0, 阶段=复苏初期
# 2026-01-03 13:29:00,333 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:00,563 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:00,566 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:01,825 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=48.0, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:29:02,041 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:02,251 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:02,255 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:03,630 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=36.1, 阶段=突破在即
# 2026-01-03 13:29:03,847 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:04,058 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:04,061 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:05,510 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-3.1, 阶段=窄幅震荡
# 2026-01-03 13:29:05,729 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:05,956 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:05,959 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:07,170 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=49.4, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:29:07,396 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:07,630 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:07,633 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:09,035 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=35.1, 阶段=突破在即
# 2026-01-03 13:29:09,250 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:09,460 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:09,464 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:10,869 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-37.1, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:29:11,159 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:11,421 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:11,425 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:12,589 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=39.8, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:29:12,804 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:13,015 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:13,019 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:14,202 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-40.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:29:14,416 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:14,626 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:14,630 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:16,089 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-41.1, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:29:16,305 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:16,516 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:16,519 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:17,737 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=13.8, 阶段=复苏初期
# 2026-01-03 13:29:17,952 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:18,163 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:18,167 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:19,336 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=17.9, 阶段=复苏初期
# 2026-01-03 13:29:19,552 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:19,766 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:19,769 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:21,233 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-35.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:29:21,460 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:21,679 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:21,683 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:23,053 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=17.5, 阶段=宽幅震荡
# 2026-01-03 13:29:23,269 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:23,480 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:23,484 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:24,649 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=23.2, 阶段=宽幅震荡
# 2026-01-03 13:29:24,868 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:25,083 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:25,086 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:29:26,507 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-33.6, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:29:26,723 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:29:26,933 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:29:26,937 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# ...
# 2026-01-03 13:30:06,967 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:07,178 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:07,181 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:08,373 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=35.8, 阶段=突破在即
# 2026-01-03 13:30:08,588 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:08,799 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:08,802 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:09,975 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=32.4, 阶段=突破在即
# 2026-01-03 13:30:10,191 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:10,402 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:10,405 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:11,611 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-32.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:11,875 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:12,111 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:12,114 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:13,352 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-19.8, 阶段=破位风险
# 2026-01-03 13:30:13,569 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:13,779 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:13,783 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:15,000 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-27.9, 阶段=熊市反弹
# 2026-01-03 13:30:15,217 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:15,427 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:15,432 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:16,662 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-30.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:16,894 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:17,113 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:17,116 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:18,541 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-10.9, 阶段=熊市筑底
# 2026-01-03 13:30:18,757 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:18,968 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:18,971 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:20,376 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-53.8, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:20,595 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:20,805 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:20,809 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:21,986 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-48.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:22,201 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:22,412 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:22,415 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:23,629 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-45.9, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:23,845 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:24,070 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:24,073 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:25,462 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-4.9, 阶段=宽幅震荡
# 2026-01-03 13:30:25,677 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:25,888 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:25,892 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:27,276 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-6.2, 阶段=窄幅震荡
# 2026-01-03 13:30:27,530 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:27,748 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:27,751 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:28,923 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=32.2, 阶段=突破在即
# 2026-01-03 13:30:29,137 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:29,347 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:29,350 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:30,556 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-45.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:30,770 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:31,017 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:31,020 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:32,277 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=22.9, 阶段=突破在即
# 2026-01-03 13:30:32,496 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:32,720 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:32,723 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:33,893 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=49.1, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:30:34,109 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:34,329 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:34,332 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:35,723 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=20.7, 阶段=突破在即
# 2026-01-03 13:30:35,940 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:36,151 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:36,155 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:37,529 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-5.8, 阶段=宽幅震荡
# 2026-01-03 13:30:37,745 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:37,955 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:37,958 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:39,146 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-35.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:39,360 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:39,570 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:39,573 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:40,758 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-4.0, 阶段=窄幅震荡
# 2026-01-03 13:30:40,973 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:41,183 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:41,187 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:42,433 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=39.3, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:30:42,661 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:42,871 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:42,874 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:44,069 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-20.3, 阶段=破位风险
# 2026-01-03 13:30:44,284 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:44,494 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:44,498 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:45,979 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-28.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:46,193 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:46,403 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:46,407 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:47,790 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-44.8, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:48,005 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:48,224 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:48,228 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:49,402 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-35.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:49,618 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:49,830 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:49,833 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:51,108 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-41.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:51,355 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:51,606 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:51,609 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:52,786 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-36.6, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:53,026 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:53,241 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:53,244 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:53,245 - INFO - 回测进度: 51/77 (2023-07-24)
# 2026-01-03 13:30:54,423 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-53.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:54,638 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:54,849 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:54,852 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:56,047 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=26.5, 阶段=突破在即
# 2026-01-03 13:30:56,263 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:56,477 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:56,480 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:57,905 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-47.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:30:58,150 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:30:58,362 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:30:58,366 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:30:59,764 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=9.5, 阶段=复苏初期
# 2026-01-03 13:30:59,982 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:00,193 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:00,197 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:01,472 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-8.0, 阶段=窄幅震荡
# 2026-01-03 13:31:01,699 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:01,910 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:01,913 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:03,111 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-61.7, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:03,330 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:03,541 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:03,544 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:04,737 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-48.2, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:04,954 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:05,165 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:05,168 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:06,433 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=6.4, 阶段=复苏初期
# 2026-01-03 13:31:06,649 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:06,864 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:06,868 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:08,089 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=13.6, 阶段=复苏初期
# 2026-01-03 13:31:08,305 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:08,519 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:08,522 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:09,730 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-55.1, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:09,945 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:10,156 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:10,159 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:11,410 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-50.3, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:11,707 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:12,105 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:12,108 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:13,942 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-1.2, 阶段=宽幅震荡
# 2026-01-03 13:31:14,409 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:14,712 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:14,715 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:16,350 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-54.8, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:16,705 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:17,087 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:17,090 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:18,807 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-40.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:19,161 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:19,508 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:19,511 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:21,295 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=35.2, 阶段=突破在即
# 2026-01-03 13:31:21,587 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:21,891 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:21,894 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:23,370 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=34.8, 阶段=突破在即
# 2026-01-03 13:31:23,587 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:23,799 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:23,802 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:24,976 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=18.0, 阶段=突破在即
# 2026-01-03 13:31:25,193 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:25,408 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:25,413 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:26,640 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=2.3, 阶段=窄幅震荡
# 2026-01-03 13:31:26,856 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:27,130 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:27,133 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:28,336 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-1.6, 阶段=复苏初期
# 2026-01-03 13:31:28,554 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:28,769 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:28,772 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:29,945 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=43.5, 阶段=牛市确认(全周期共振)
# 2026-01-03 13:31:30,162 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:30,372 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:30,375 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:31,586 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-12.9, 阶段=见顶回落
# 2026-01-03 13:31:31,801 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:32,013 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:32,016 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:33,233 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-50.0, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:33,447 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:33,658 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:33,661 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:34,854 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-47.4, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:35,068 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:35,279 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:35,282 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:36,543 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-58.9, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:36,767 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:36,978 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:36,981 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:38,156 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=3.2, 阶段=宽幅震荡
# 2026-01-03 13:31:38,372 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:38,588 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:38,591 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:39,766 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-28.5, 阶段=熊市确认(全周期共振)
# 2026-01-03 13:31:39,981 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:40,192 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:40,195 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:41,447 - INFO - 市场趋势分析完成: 000001.XSHG, 综合得分=-17.3, 阶段=熊市反弹
# 2026-01-03 13:31:41,662 - INFO - 🔍 开始IBD风格市场分析: 000001.XSHG
# 2026-01-03 13:31:41,874 - INFO - 获取价格数据成功: 000001.XSHG, 2025-04-18 to 2026-01-03
# 2026-01-03 13:31:41,877 - INFO - 🔍 IBD分析完成: rally_attempt, 得分: 10.0
# 2026-01-03 13:31:41,878 - INFO - 回测完成: 共77个信号, 5日准确率=51.9%, 耗时=134.9秒
# ✅ Phase 2 完整回测完成!
#    总信号数: 239
#    短期准确率: 55.6%
#    中期准确率: 62.3%
#    长期准确率: 66.9%
#    市场状态准确率: 43.1%

# %%
# Phase 2 结果报告
if 'phase2_result' in dir() and phase2_result:
    backtester = SignalBacktester()
    report = backtester.generate_report(phase2_result)
    display(Markdown(report))
# Out:
# # 市场趋势信号回测报告 (增强版)
#
# ## 回测概况
#
# | 项目 | 值 |
# |------|-----|
# | 回测时间 | 2026-01-03 13:31:41 |
# | 回测区间 | 2014-11-17 ~ 2024-08-16 |
# | 基准指数 | 000001.XSHG |
# | 总信号数 | 239 |
# | 看多信号 | 45 |
# | 看空信号 | 37 |
# | 中性信号 | 157 |
# | 耗时 | 0.0秒 |
#
# ## 综合准确率
#
# | 持有期 | 准确率 |
# |--------|--------|
# | 5日 | 54.8% |
# | 10日 | 55.6% |
# | 20日 | 69.0% |
# | 60日 | 69.0% |
#
# ## 分周期准确率
#
# | 周期 | 验证期 | 准确率 | 看多准确 | 看空准确 |
# |------|--------|--------|----------|----------|
# | 短期 | 5日 | 55.6% | 52.8% | 44.2% |
# | 中期 | 20日 | 62.3% | 52.7% | 43.6% |
# | 长期 | 60日 | 66.9% | 48.1% | 53.8% |
#
# ## 市场状态准确率
#
# | 状态类别 | 60日准确率 |
# |----------|------------|
# | 牛市系列 | 29.6% |
# | 熊市系列 | 19.2% |
# | 震荡系列 | 57.9% |
# | **综合** | **43.1%** |
#
# ## 分类信号表现
#
# ### 看多信号
# | 指标 | 值 |
# |------|-----|
# | 信号数量 | 45 |
# | 5日胜率 | 51.1% |
# | 5日平均收益 | 0.62% |
# | 20日平均收益 | 1.90% |
#
# ### 看空信号
# | 指标 | 值 |
# |------|-----|
# | 信号数量 | 37 |
# | 5日胜率 | 37.8% |
# | 5日平均收益 | 0.08% |
# | 20日平均收益 | -0.08% |
#
# ## 年度统计
#
# | 年份 | 信号数 | 5日准确 | 20日准确 | 60日准确 | 短期准确 | 中期准确 | 长期准确 |
# |------|--------|---------|----------|----------|----------|----------|----------|
# | 2014 | 4 | 100% | 100% | 100% | 100% | 50% | 100% |
# | 2015 | 24 | 38% | 46% | 33% | 50% | 42% | 33% |
# | 2016 | 25 | 56% | 80% | 96% | 60% | 56% | 96% |
# | 2017 | 24 | 75% | 83% | 79% | 67% | 75% | 88% |
# | 2018 | 25 | 52% | 68% | 52% | 52% | 60% | 44% |
# | 2019 | 24 | 54% | 83% | 79% | 54% | 71% | 75% |
# | 2020 | 24 | 67% | 75% | 67% | 54% | 79% | 71% |
# | 2021 | 25 | 52% | 64% | 60% | 60% | 60% | 56% |
# | 2022 | 24 | 42% | 38% | 67% | 46% | 38% | 62% |
# | 2023 | 24 | 46% | 79% | 92% | 46% | 79% | 83% |
# | 2024 | 16 | 62% | 69% | 56% | 62% | 69% | 50% |

# %% [markdown]
# ---
#
# ## 6. 结果分析与可视化

# %%
# 可视化: 准确率热力图
if 'phase2_result' in dir() and phase2_result:
    try:
        viz = BacktestVisualization(phase2_result)
        
        # 准确率热力图
        fig = viz.create_accuracy_heatmap()
        if fig:
            fig.show()
    except Exception as e:
        print(f"可视化失败: {e}")

# %%
# 可视化: 年度准确率
if 'phase2_result' in dir() and phase2_result:
    try:
        fig = viz.create_yearly_accuracy_bar()
        if fig:
            fig.show()
    except Exception as e:
        print(f"年度可视化失败: {e}")

# %%
# 可视化: 市场状态时间线
if 'phase2_result' in dir() and phase2_result:
    try:
        fig = viz.create_market_state_timeline()
        if fig:
            fig.show()
    except Exception as e:
        print(f"时间线可视化失败: {e}")

# %%
# 保存HTML报告
if 'phase2_result' in dir() and phase2_result:
    try:
        html_path = "/home/taotao/dev/QuantTest/TRQuant/output/market_trend_backtest_report.html"
        viz.generate_html_report(html_path)
        print(f"\n📄 HTML报告已保存: {html_path}")
    except Exception as e:
        print(f"HTML报告生成失败: {e}")
# Out:
# 2026-01-03 13:31:42,789 - INFO - HTML报告已保存: /home/taotao/dev/QuantTest/TRQuant/output/market_trend_backtest_report.html
# 📄 HTML报告已保存: /home/taotao/dev/QuantTest/TRQuant/output/market_trend_backtest_report.html

# %% [markdown]
# ---
#
# ## 7. 参数优化建议

# %%
# 参数优化分析
if 'phase2_result' in dir() and phase2_result:
    
    print("\n" + "="*60)
    print("📈 参数优化建议")
    print("="*60)
    
    # 分析各周期表现
    print("\n1. 周期权重调整建议:")
    print(f"   短期准确率: {phase2_result.short_accuracy_5d:.1f}% (当前权重20%)")
    print(f"   中期准确率: {phase2_result.medium_accuracy_20d:.1f}% (当前权重30%)")
    print(f"   长期准确率: {phase2_result.long_accuracy_60d:.1f}% (当前权重50%)")
    
    if phase2_result.long_accuracy_60d > phase2_result.short_accuracy_5d + 10:
        print("   ✅ 长期信号更可靠，可考虑增加长期权重到55-60%")
    
    # 分析看多看空表现
    print("\n2. 信号类型分析:")
    print(f"   看多5日胜率: {phase2_result.win_rate_bullish:.1f}%")
    print(f"   看空5日胜率: {phase2_result.win_rate_bearish:.1f}%")
    
    if phase2_result.win_rate_bearish < 50:
        print("   ⚠️ 看空信号胜率较低，建议:")
        print("      - 提高看空阈值 (如从-30提高到-40)")
        print("      - 增加确认条件 (多周期共振)")
    
    # 分析市场状态
    print("\n3. 市场状态识别优化:")
    print(f"   牛市识别准确率: {phase2_result.bull_state_accuracy:.1f}%")
    print(f"   熊市识别准确率: {phase2_result.bear_state_accuracy:.1f}%")
    print(f"   震荡识别准确率: {phase2_result.volatile_state_accuracy:.1f}%")
# Out:
# ============================================================
# 📈 参数优化建议
# ============================================================
#
# 1. 周期权重调整建议:
#    短期准确率: 55.6% (当前权重20%)
#    中期准确率: 62.3% (当前权重30%)
#    长期准确率: 66.9% (当前权重50%)
#    ✅ 长期信号更可靠，可考虑增加长期权重到55-60%
#
# 2. 信号类型分析:
#    看多5日胜率: 51.1%
#    看空5日胜率: 37.8%
#    ⚠️ 看空信号胜率较低，建议:
#       - 提高看空阈值 (如从-30提高到-40)
#       - 增加确认条件 (多周期共振)
#
# 3. 市场状态识别优化:
#    牛市识别准确率: 29.6%
#    熊市识别准确率: 19.2%
#    震荡识别准确率: 57.9%

# %% [markdown]
# ---
#
# ## 8. 结论与后续改进

# %%
# 总结报告
if 'phase2_result' in dir() and phase2_result:
    
    summary = f"""
## 📋 回测总结报告

### 回测概况
- **回测区间**: 2014-11-17 ~ 2024-08-16 (约10年)
- **总信号数**: {phase2_result.total_signals}
- **看多/看空/中性**: {phase2_result.bullish_signals}/{phase2_result.bearish_signals}/{phase2_result.neutral_signals}

### 准确率汇总

| 验证周期 | 准确率 | 评价 |
|----------|--------|------|
| 短期(5日) | {phase2_result.short_accuracy_5d:.1f}% | {'✅ 及格' if phase2_result.short_accuracy_5d > 50 else '⚠️ 需优化'} |
| 中期(20日) | {phase2_result.medium_accuracy_20d:.1f}% | {'✅ 良好' if phase2_result.medium_accuracy_20d > 55 else '⚠️ 需优化'} |
| 长期(60日) | {phase2_result.long_accuracy_60d:.1f}% | {'✅ 良好' if phase2_result.long_accuracy_60d > 60 else '⚠️ 需优化'} |

### 关键发现

1. **长期信号更可靠**: 长期准确率({phase2_result.long_accuracy_60d:.0f}%)高于短期({phase2_result.short_accuracy_5d:.0f}%)
2. **震荡市识别最好**: {phase2_result.volatile_state_accuracy:.0f}%准确率
3. **看空信号需优化**: 看空5日胜率仅{phase2_result.win_rate_bearish:.0f}%

### 后续改进方向

1. 调整看空信号阈值，增加确认条件
2. 考虑增加长期信号权重
3. 针对不同市场周期使用动态参数
4. 增加更多A股特色指标（如主力资金、板块轮动）
"""
    
    display(Markdown(summary))
# Out:
# ## 📋 回测总结报告
#
# ### 回测概况
# - **回测区间**: 2014-11-17 ~ 2024-08-16 (约10年)
# - **总信号数**: 239
# - **看多/看空/中性**: 45/37/157
#
# ### 准确率汇总
#
# | 验证周期 | 准确率 | 评价 |
# |----------|--------|------|
# | 短期(5日) | 55.6% | ✅ 及格 |
# | 中期(20日) | 62.3% | ✅ 良好 |
# | 长期(60日) | 66.9% | ✅ 良好 |
#
# ### 关键发现
#
# 1. **长期信号更可靠**: 长期准确率(67%)高于短期(56%)
# 2. **震荡市识别最好**: 58%准确率
# 3. **看空信号需优化**: 看空5日胜率仅38%
#
# ### 后续改进方向
#
# 1. 调整看空信号阈值，增加确认条件
# 2. 考虑增加长期信号权重
# 3. 针对不同市场周期使用动态参数
# 4. 增加更多A股特色指标（如主力资金、板块轮动）

# %% [markdown]
# ---
#
# ## 📚 参考资料
#
# ### 核心模块
#
# | 模块 | 路径 | 说明 |
# |------|------|------|
# | 回测框架 | `core/signal_backtest.py` | SignalBacktester, run_phase1_backtest, run_phase2_backtest |
# | 可视化 | `core/backtest_visualization.py` | BacktestVisualization |
# | 市场状态定义 | `core/market_state_definitions.py` | 14种状态量化定义 |
# | A股指标 | `core/astock_indicators.py` | 北向资金、融资融券、市场宽度 |
#
# ### 相关Notebook
#
# | Notebook | 说明 |
# |----------|------|
# | `01_market_trend_comprehensive.ipynb` | 应用市场环境判断 (使用本notebook验证的方法) |
# | `00_system_architecture_workflow.ipynb` | 系统架构总览 |
